# %% [markdown]
# # Etapa 2 - Análise dos dados

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from sqlite3 import connect
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %matplotlib inline

# %%
conn = connect("Passei_Direto_DB.sqlite")
cursor = conn.cursor()

cursor = cursor.execute("SELECT * FROM base_de_dados")
df = pd.DataFrame(data=cursor.fetchall(),
                  columns=["IdStudent", "RegisteredDate", "UniversityId", "CourseId", "SignupSource",
                           "PaymentDate", "PlanType", "NameCourse", "NameUniversity", "Subscriber",
                          "Logins", "Follows"])
df
# Out:
#                                                IdStudent  \
# 0      0cade9bf00234e3789afc76250e4042bc1b70784ae7004...
# 1      8a501cab6c0a5a7e98a86f51a6264d81cdb562f4e99106...
# 2      b8a39150d98d746853087a4107e9290976cb6c99d16a29...
# 3      0f6c90f966a70b84b70ea84a62d2e46ae4a2a237670815...
# 4      388bf84cffb3219384cd7a92153cf00f3b1416e4ff1473...
# 5      5764c7b7c75f304749a9fa76e2cc811eb9c48535c495af...
# 6      4522694e98b51ba30fec3eb8842c795b9d93ad6bf8a991...
# 7      0360730b79c8ecd04d08d5352f18d549e849ce90bde52f...
# 8      668514e190e792018e95c352e37a55040f00b2b716115a...
# 9      7c743c3365d9b969694b4c915841ccb2a207f40a82ee70...
# 10     09e1497357395b82547323cde92029f483626624de6135...
# 11     29037b0a52c5b576d32ac5842fd5b7e5991c5bef93150f...
# 12     9f3a457a426cae314793bc19bddc9a2a59cd01f54ef8f3...
# 13     f0ec48700197a23c4c02c97a3b944f9857b72f4acaf94a...
# 14     57e35f4dbe1f277de0578ef0e999edb35aff88ad7822b9...
# 15     5247dbaa0d6cac43681b2b1ccfb70cc9bb409836d3eee7...
# 16     603aec86462715af4fd6594fa24a13a357390c8f546eeb...
# 17     7e7d6eb03294f5a7fa17c948017cd5fc97980154b1c816...
# 18     735218971fa78ff17a69501ff732af9099eea5bb17d937...
# 19     3c912e19c1203ff04847e56b4f7ef06d242a148e5f8e64...
# 20     b6fe151b0366918218ee2bb84d88cd77c575f4aa414e0d...
# 21     00d5fe78fda37e694fa0bec295f12b407767171fd95dcc...
# 22     b878fe5674e4b3ba6029ad22046fc86cf78bfdacf9b0d7...
# 23     bb3d78fcdf8cd6905e37fd485739be730079adced48171...
# 24     c0338a94a24d4ceba800a02d4ef8a39994e197cce47896...
# 25     c840e611b4173947993043d9b3c2f6ca63b126b862a71a...
# 26     66af95179bf7fbb111cbfde5435858eda264543da6c73f...
# 27     c0006c10a16bde58d938bb7cf0fe84f5e890432af3622f...
# 28     641c1b88e0ec83a17cd9d26d4fe93306d264c866ad51c3...
# 29     2c6408e3b01e21986a6652f8027854ca060ad6c970488c...
# ...                                                  ...
# 59972  cd3cab2eca1114ea5df1bc38609d795865c750a94fbbbd...
# 59973  cdf1aee17a1f9e0cbb7557865c070b75d3018aac19c0c4...
# 59974  1e7a0ad2dc3ffa6f1273cd2ee8bd9a8e6eda0327814c3d...
# 59975  fff8dd2f497777e1c8c661c66cc00568733f61012f7339...
# 59976  5cbbb35213ac5d5b8bc900582dddc290e7daed836d3c5d...
# 59977  ec8026cf7463976d9184fa10505fab06a80871de92d2b7...
# 59978  7b765b798abdc07ddd83eb32cc1e077249048bd5ae08ac...
# 59979  02efd60b98928bb3fb03bec8e0a049e8abc887b13b37f3...
# 59987                        None     None
# 59988                        None     None
# 59989                        None     None
# 59990                        None     None
# 59991                        None     None
# 59992                        None     None
# 59993                        None     None
# 59994                        None     None
# 59995                        None     None
# 59996                        None     None
# 59997  2017-11-30 23:56:24.145972   Mensal
# 59998                        None     None
# 59999                        None     None
# 60000                        None     None
# 60001                        None     None
#
#                                           NameCourse      NameUniversity  \
# 0                                Engenharia Elétrica                UERJ
# 1                     Economia / Ciências Econômicas                UERJ
# 2                                            Direito             PUC-RIO
# 3                                Ciências Ambientais              UNIRIO
# 4                                 Engenharia Química                UFSJ
# 5                     Economia / Ciências Econômicas                UFSC
# 6                                            Direito                UFRJ
# 7                             Engenharia de Produção              PUC-PR
# 8                                Ciências Ambientais              UNIRIO
# 9                               Engenharia Ambiental                UFOP
# 10                                           Química                 UFV
# 11                                     Administração         ESTÁCIO EAD
# 12                                       Odontologia              UNIFOA
# 13                                         Agronomia                 UFV
# 14                               Engenharia Elétrica                UFSJ
# 15                              Engenharia Ambiental                 UNB
# 16                            Engenharia de Produção              UFSCAR
# 17                                    Serviço Social                 UNB
# 18                                           Direito           PUC-MINAS
# 19                            Engenharia Aeronáutica                 UFU
# 20                                           Direito             ESTÁCIO
# 21                               Engenharia Elétrica                 UFU
# 22                               Engenharia Elétrica                 UVV
# 23                                           Direito                 UFG
# 24                                  Engenharia Civil                UFMG
# 25                               Engenharia Elétrica                UFES
# 26     Comunicação Social - Publicidade e Propaganda             PUC-RIO
# 27                                           Direito                 UFF
# 28                                         Pedagogia                UERJ
# 29                                          Nutrição              USP-SP
# ...                                              ...                 ...
# 59972                                     Matemática             ESTÁCIO
# 59973             Contabilidade / Ciências Contábeis          ANHANGUERA
# 59974                                  Administração                 UVA
# 59975                                     Matemática          UNIGRANRIO
# 59976                             Gestão Empresarial               Fatec
# 59977                                  Administração             ESTÁCIO
# 59978                                  Administração           UNIBRATEC
# 59979                           Automação Industrial    SENAI RIO DO SUL
# 59980                                  Administração                UNIP
# 59981         Comunicação Social - Relações Públicas        UNIFIAM-FAAM
# 59982                                Educação Física                UFPE
# 59983                               Engenharia Civil           PUC-MINAS
# 59984                                       Medicina                ESUV
# 59985                                        Direito                FASB
# 59986                           Design de Interiores                 FIC
# 59987                                    Odontologia  UNINASSAU TERESINA
# 59988                                      Pedagogia          UNIASSELVI
# 59989             Veterinária / Medicina Veterinária          ANHANGUERA
# 59990             Contabilidade / Ciências Contábeis                FAEL
# 59991                                        Direito              USP-SP
# 59992              Farmácia / Ciências Farmacêuticas                UCBR
# 59993               Agricultura / Ciências Agrícolas                UNIP
# 59994                                    Odontologia            SLMANDIC
# 59995                               Engenharia Civil             ESTÁCIO
# 59996                         Engenharia de Produção     UNIAN - NITERÓI
# 59997                                    Arquitetura                UNIP
# 59998                                     Enfermagem              USP-SP
# 59999                                      Pedagogia             UNINTER
# 60000                                        Direito               UNAMA
# 60001                                       Nutrição             ESTÁCIO
#
#       Subscriber  Logins  Follows
# 0            Not       6      5.0
# 1            Not       1      5.0
# 2            Not       4      5.0
# 3            Not       6      7.0
# 4            Not       2      5.0
# 5            Not       2      5.0
# 6            Not       1      9.0
# 7            Not       2      5.0
# 8            Not       3      5.0
# 9            Not       8      7.0
# 10           Not       1      5.0
# 11           Yes      14      5.0
# 12           Not      15      1.0
# 13           Not       1      6.0
# 14           Not      17      6.0
# 15           Not       1      6.0
# 16           Not       1      5.0
# 17           Not       4      5.0
# 18           Not       5      9.0
# 19           Not       1      5.0
# 20           Not       5      4.0
# 21           Not       5      5.0
# 22           Not       1      5.0
# 23           Not       2      5.0
# 24           Not       2      2.0
# 25           Not       1      5.0
# 26           Not       1      6.0
# 27           Not       4      9.0
# 28           Not       2      8.0
# 29           Not       1      6.0
# ...          ...     ...      ...
# 59972        Not       1      5.0
# 59973        Not       1      NaN
# 59974        Not       1      5.0
# 59975        Not       3      5.0
# 59976        Not      15      NaN
# 59977        Not       1      6.0
# 59978        Not       1      5.0
# 59979        Not       1      5.0
# 59980        Not       1      6.0
# 59981        Not       1      5.0
# 59982        Not       1      6.0
# 59983        Not       2      6.0
# 59984        Not       1      5.0
# 59985        Not       1      5.0
# 59986        Not       2      6.0
# 59987        Not       1      6.0
# 59988        Not       1      6.0
# 59989        Not       7      5.0
# 59990        Not       1      6.0
# 59991        Not       6      5.0
# 59992        Not       1      5.0
# 59993        Not       1      5.0
# 59994        Not       1      6.0
# 59995        Not       1      5.0
# 59996        Not       1      5.0
# 59997        Yes       1      5.0
# 59998        Not       1      5.0
# 59999        Not       1      6.0
# 60000        Not       1      5.0
# 60001        Not       1      5.0
#
# [60002 rows x 12 columns]

# %% [markdown]
# ## Top 5 cursos

# %%
# Filtrando colunas desejadas

top_courses = df[[column for column in df.columns if column in ["IdStudent", "NameCourse"]]]
top_courses.head()
# Out:
#                                            IdStudent  \
# 0  0cade9bf00234e3789afc76250e4042bc1b70784ae7004...
# 1  8a501cab6c0a5a7e98a86f51a6264d81cdb562f4e99106...
# 2  b8a39150d98d746853087a4107e9290976cb6c99d16a29...
# 3  0f6c90f966a70b84b70ea84a62d2e46ae4a2a237670815...
# 4  388bf84cffb3219384cd7a92153cf00f3b1416e4ff1473...
#
#                        NameCourse
# 0             Engenharia Elétrica
# 1  Economia / Ciências Econômicas
# 2                         Direito
# 3             Ciências Ambientais
# 4              Engenharia Química

# %%
# Agrupando por curso

top_courses = top_courses.groupby(["NameCourse"], as_index=False).count()
top_courses.head()
# Out:
#                                      NameCourse  IdStudent
# 0                                 Administração       4168
# 1  Administração Hospitalar / Gestão Hospitalar         54
# 2                   Administração Internacional         36
# 3                         Administração Pública        169
# 4              Agricultura / Ciências Agrícolas          6

# %%
# Renomeando colunas

top_courses = top_courses.rename(columns={"IdStudent": "Qnt"})
top_courses.head()
# Out:
#                                      NameCourse   Qnt
# 0                                 Administração  4168
# 1  Administração Hospitalar / Gestão Hospitalar    54
# 2                   Administração Internacional    36
# 3                         Administração Pública   169
# 4              Agricultura / Ciências Agrícolas     6

# %%
# Ordenando e filtrando os Top5 cursos

top_courses = top_courses.sort_values(by="Qnt", ascending=False)[:5]
top_courses
# Out:
#                              NameCourse   Qnt
# 101                             Direito  9916
# 0                         Administração  4168
# 139                    Engenharia Civil  3562
# 85   Contabilidade / Ciências Contábeis  2714
# 364                           Pedagogia  2566

# %%
# Plot

plt.figure(figsize=(15, 10))
plt.bar(top_courses["NameCourse"], top_courses["Qnt"], color="#ff7300")
plt.xlabel("Cursos", fontsize=18)
plt.ylabel("Quantidade de Estudantes", fontsize=18)
plt.title("Top 5 cursos", fontsize=25)
plt.show()

# %% [markdown]
# ## Top 3 Universidades

# %%
# Filtrando colunas desejadas

top_universities = df[[column for column in df.columns if column in ["IdStudent", "NameUniversity", "Subscriber"]]]
top_universities.head()
# Out:
#                                            IdStudent NameUniversity Subscriber
# 0  0cade9bf00234e3789afc76250e4042bc1b70784ae7004...           UERJ        Not
# 1  8a501cab6c0a5a7e98a86f51a6264d81cdb562f4e99106...           UERJ        Not
# 2  b8a39150d98d746853087a4107e9290976cb6c99d16a29...        PUC-RIO        Not
# 3  0f6c90f966a70b84b70ea84a62d2e46ae4a2a237670815...         UNIRIO        Not
# 4  388bf84cffb3219384cd7a92153cf00f3b1416e4ff1473...           UFSJ        Not

# %%
# Filtrando alunos premium

top_universities = top_universities[top_universities["Subscriber"] == "Yes"]
top_universities.head()
# Out:
#                                              IdStudent NameUniversity  \
# 11   29037b0a52c5b576d32ac5842fd5b7e5991c5bef93150f...    ESTÁCIO EAD
# 126  b2bace77d15c3dfaf57bf9916f0e9924d12f89bdc0624c...       CEFET/MG
# 312  f423d6fe2f8964db634c7806e03b0f6567e992e994f06f...        ESTÁCIO
# 317  55ccbe518d2edbbd527eddca1431c7f7f3a4676bdbee38...        ESTÁCIO
# 318  b1b0f63fe3e4820cb082531af7c8911cd380e5ec8fe822...        ESTÁCIO
#
#     Subscriber
# 11         Yes
# 126        Yes
# 312        Yes
# 317        Yes
# 318        Yes

# %%
# Agrupando por Universidade

top_universities = top_universities.groupby(["NameUniversity"], as_index=False).count()
top_universities.head()
# Out:
#   NameUniversity  IdStudent  Subscriber
# 0     ANHANGUERA          2           2
# 1     Anhanguera          6           6
# 2            CDL          1           1
# 3       CEFET/MG          2           2
# 4       CEFET/RJ          2           2

# %%
# Renomeando colunas

top_universities = top_universities.rename(columns={"IdStudent": "Qnt"})
top_universities.head()
# Out:
#   NameUniversity  Qnt  Subscriber
# 0     ANHANGUERA    2           2
# 1     Anhanguera    6           6
# 2            CDL    1           1
# 3       CEFET/MG    2           2
# 4       CEFET/RJ    2           2

# %%
# Ordenando e filtrando os Top5 cursos

top_universities = top_universities.sort_values(by="Qnt", ascending=False)[:3]
top_universities
# Out:
#     NameUniversity  Qnt  Subscriber
# 9          ESTÁCIO  359         359
# 10     ESTÁCIO EAD   85          85
# 118        UNINTER   72          72

# %%
# Plot

plt.figure(figsize=(10, 8))
plt.bar(top_universities["NameUniversity"], top_universities["Qnt"], color="#ff7300")
plt.xlabel("Universidades", fontsize=18)
plt.ylabel("Quantidade de Estudantes Premuim", fontsize=18)
plt.title("Top 3 Universidades", fontsize=25)
t3 = plt.show()

# %% [markdown]
# ## Tentando prever se o estudante é Premuim ou não

# %% [markdown]
# ### Limpando dados

# %%
df.head()
# Out:
#                                            IdStudent  \
# 0  0cade9bf00234e3789afc76250e4042bc1b70784ae7004...
# 1  8a501cab6c0a5a7e98a86f51a6264d81cdb562f4e99106...
# 2  b8a39150d98d746853087a4107e9290976cb6c99d16a29...
# 3  0f6c90f966a70b84b70ea84a62d2e46ae4a2a237670815...
# 4  388bf84cffb3219384cd7a92153cf00f3b1416e4ff1473...
#
#                RegisteredDate  UniversityId  CourseId SignupSource  \
# 0  2012-09-06 17:27:11.370000        664704   1199555     Facebook
# 1  2012-09-05 15:31:08.090000        664704   1199521     Facebook
# 2  2012-08-17 10:00:04.270000        661625   1199517     Facebook
# 3  2012-10-22 21:16:52.157000        664768   1199491     Facebook
# 4  2012-10-24 01:48:53.700000        663106   1199573     Facebook
#
#   PaymentDate PlanType                      NameCourse NameUniversity  \
# 0        None     None             Engenharia Elétrica           UERJ
# 1        None     None  Economia / Ciências Econômicas           UERJ
# 2        None     None                         Direito        PUC-RIO
# 3        None     None             Ciências Ambientais         UNIRIO
# 4        None     None              Engenharia Química           UFSJ
#
#   Subscriber  Logins  Follows
# 0        Not       6      5.0
# 1        Not       1      5.0
# 2        Not       4      5.0
# 3        Not       6      7.0
# 4        Not       2      5.0

# %%
# Removendo colunas

df_class = df[[column for column in df.columns if column not in ["IdStudent", "RegisteredDate", "SignupSource",
                                                                 "PaymentDate", "PlanType", "NameCourse", "NameUniversity"]]]
df_class.head()
# Out:
#    UniversityId  CourseId Subscriber  Logins  Follows
# 0        664704   1199555        Not       6      5.0
# 1        664704   1199521        Not       1      5.0
# 2        661625   1199517        Not       4      5.0
# 3        664768   1199491        Not       6      7.0
# 4        663106   1199573        Not       2      5.0

# %%
# Removendo linhas com valores missing

df_class = df_class.dropna(axis="index")

# %%
# Entendendo a proporção dos dados

subs = df_class["Subscriber"].value_counts()
subs.plot(kind='bar', color="#ff7300")

# %% [markdown]
# ## Data Munging

# %% [markdown]
# Como os dados estão desbalanceados, será usada a técnica de balanceamento por Undersampling.

# %%
# Contando classes
count_class_not, count_class_yes = df_class.Subscriber.value_counts()

# Divide por Subscriber
df_class_not = df_class[df_class['Subscriber'] == "Not"]
df_class_yes = df_class[df_class['Subscriber'] == "Yes"]
df_class_not_under = df_class_not.sample(count_class_yes, replace=True)
df_over = pd.concat([df_class_not_under, df_class_yes], axis=0)

print(df_over.Subscriber.value_counts())
df_over.Subscriber.value_counts().plot(kind='bar', color="#ff7300")
# Out:
# Yes    772
# Not    772
# Name: Subscriber, dtype: int64

# %% [markdown]
# ### Dividindo os dados em treino e teste

# %%
x = df_over[[column for column in df_over.columns if column not in ["Subscriber"]]]
y = df_over["Subscriber"]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### Árvore de Decisão

# %%
tree = DecisionTreeClassifier()

model_tree = tree.fit(x_train, y_train)

predict = model_tree.score(x_test, y_test)

predict
# Out:
# 0.7758620689655172

# %% [markdown]
# ### Naive Bayes

# %%
nb = GaussianNB()

model_nb = nb.fit(x_train, y_train)

predict = model_nb.score(x_test, y_test)

predict
# Out:
# 0.5280172413793104

# %% [markdown]
# ### Regressão Logística

# %%
lr = LogisticRegression()

model_lr = lr.fit(x_train, y_train)

predict = model_lr.score(x_test, y_test)

predict
# Out:
# C:\Users\Joao_\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.4870689655172414

# %% [markdown]
# ## Considerações Finais

# %% [markdown]
# Com o objetivo de auxiliar o time de marketing do PD, desenvolveu-se um modelo de Machine Learning com 77% de precisão (Modelo Árvore de Decisão) para prever se um dado usuário deveria ser ou não do tipo Premium. O objetivo desse modelo é detectar os usuários que através de uma ação de marketing terão maior tendência de se tornarem Premuim.
